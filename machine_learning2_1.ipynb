# %% [markdown]
# <a href="https://colab.research.google.com/github/Sainirmit/MachineLearning/blob/main/machine_learning2_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ---
# # **Introduction to Machine Learning**
#
# # **Chapter 2.1 Multiple linear regression (MLR)**
# ---

# %% [markdown]
# ## Import libraries

# %%
import numpy as np                  # for scientific computing (e.g. culclations with array)
import pandas as pd                 # for data manipulation and analysis
import matplotlib.pyplot as plt     # for visualization
import seaborn as sns               # for visualization

# %% [markdown]
# ## Dataset loading

# %% [markdown]
# This dataset is from Kaggle.
# For more information about this dataset, see
# https://www.kaggle.com/datasets/camnugent/california-housing-prices

# %%
#Download dataset from Github
# !wget https://raw.githubusercontent.com/a-ymst/IntroductionToMachineLearning/main/Datasets/housing.csv

df_housing = pd.read_csv("housing.csv")     # making data frame object from csv file
df_housing
# Out:
# --2024-08-23 18:33:11--  https://raw.githubusercontent.com/a-ymst/IntroductionToMachineLearning/main/Datasets/housing.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1423529 (1.4M) [text/plain]
# Saving to: ‘housing.csv’
#
# housing.csv         100%[===================>]   1.36M  --.-KB/s    in 0.01s
#
# 2024-08-23 18:33:11 (113 MB/s) - ‘housing.csv’ saved [1423529/1423529]
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20640 rows x 10 columns]

# %%
df_housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
df_housing.hist(bins=50, figsize=[10,8])
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
df_housing.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# 25%        296.000000    787.000000    280.000000       2.563400
# 50%        435.000000   1166.000000    409.000000       3.534800
# 75%        647.000000   1725.000000    605.000000       4.743250
# max       6445.000000  35682.000000   6082.000000      15.000100
#
#        median_house_value
# count        20640.000000
# mean        206855.816909
# std         115395.615874
# min          14999.000000
# 25%         119600.000000
# 50%         179700.000000
# 75%         264725.000000
# max         500001.000000

# %% [markdown]
# ##🤔 **Exercise 2.1**
#
# Create a linear regression model that predicts **median_house_value** using only **median_income** column as input. Train it and check its coefficient of determination $R^2$ and MSE.

# %%
# make your code here

from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

#==========================================================

X = df_housing[['median_income']]
t = df_housing[['median_house_value']]

# Standardization
scaler = StandardScaler()
scaler.fit(X)
std_X = scaler.transform(X)  # standardization for the input

X_train, X_test, t_train, t_test = train_test_split(std_X, t, test_size=0.2)  # 20% samples will be test set


model = LinearRegression()
model.fit(X_train, t_train)

y_train = model.predict(X_train)
y_test = model.predict(X_test)

#==========================================================

R2_train = model.score(X_train, t_train)
R2_test = model.score(X_test, t_test)
rmse_train = np.sqrt(np.average((t_train - y_train)**2))
rmse_test = np.sqrt(np.average((t_test - y_test)**2))

print("W =", model.coef_)
print("b =", model.intercept_)
print("R^2_train =", R2_train)
print("R^2_test =", R2_test)
print("RMSE(train) =", rmse_train)
print("RMSE(test) =", rmse_test)


# plotting training set
plt.scatter(X_train, t_train, c="blue")
plt.scatter(X_train, y_train, c="orange")
plt.show()

# plotting test set
plt.scatter(X_test, t_test, c="blue")
plt.scatter(X_test, y_test, c="orange")
plt.show()
# Out:
# W = [[79328.22649755]]
# b = [206065.1323519]
# R^2_train = 0.47656008253219007
# R^2_test = 0.4605880538057161
# RMSE(train) = 83335.69279825473
# RMSE(test) = 85325.01186374124

# %% [markdown]
# ##🤔 **Exercise 2.2**
#
# Add freely selected features to the input $X$ of the regression model created in Exercise 2.1. Train it and check its $R^2$ and MSE.

# %%
# make your code here

from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

#==========================================================

X = df_housing[['total_rooms']]       # e.g: df_housing[["median_income", "total_rooms"]]
t = df_housing[['households']]

# Standardization
scaler = StandardScaler()
scaler.fit(X)
std_X = scaler.transform(X)  # standardization for the input

X_train, X_test, t_train, t_test = train_test_split(std_X, t, test_size=0.2)  # 20% samples will be test set

print("X_train.shape =", X_train.shape)
print("t_train.shape =", t_train.shape)
print("X_test.shape =", X_test.shape)
print("t_test.shape =", t_test.shape)


model = LinearRegression()
model.fit(X_train, t_train)

y_train = model.predict(X_train)
y_test = model.predict(X_test)

#===========================================================

R2_train = model.score(X_train, t_train)
R2_test = model.score(X_test, t_test)
rmse_train = np.sqrt(np.average((t_train - y_train)**2))
rmse_test = np.sqrt(np.average((t_test - y_test)**2))

print("W =", model.coef_)
print("b =", model.intercept_)
print("R^2_train =", R2_train)
print("R^2_test =", R2_test)
print("RMSE(train) =", rmse_train)
print("RMSE(test) =", rmse_test)
# Out:
# X_train.shape = (16512, 1)
# t_train.shape = (16512, 1)
# X_test.shape = (4128, 1)
# t_test.shape = (4128, 1)
# W = [[350.35319258]]
# b = [499.33948366]
# R^2_train = 0.846656210181989
# R^2_test = 0.8310834817861906
# RMSE(train) = 150.10296758370748
# RMSE(test) = 155.47951971581807
